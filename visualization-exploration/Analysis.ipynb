# %%
# import dependencies
import pandas as pd

# %%
#import dataset

card_data = pd.read_json('scryfall-oracle-cards.json')
card_data
# Out:
#       object                                    id  \
# 0       card  a471b306-4941-4e46-a0cb-d92895c16f8a
# 1       card  6b7baaa7-67f2-4902-a4c1-761d58cce1d4
# 2       card  86bf43b1-8d4e-4759-bb2d-0b2e03ba7012
# 3       card  7050735c-b232-47a6-a342-01795bfd0d46
# 4       card  9c5e9b5f-6e71-4afc-abbd-ba4c788a3240
# ...      ...                                   ...
# 35744   card  d6695fa8-881c-407c-91d9-3ac770372d35
# 35745   card  4d5edf4f-5695-42fc-9e57-c4faef60fbc3
# 35746   card  22a6a5f1-1405-4efb-af3e-e1f58d664e99
# 35747   card  09f06f55-7918-46c4-80ff-0bf39e091a4a
# 35748   card  1ecc983e-bbe3-4bc1-97e9-e40ead987ef0
#
#                                   oracle_id    multiverse_ids   mtgo_id  \
# 0      00037840-6089-42ec-8c5c-281f9f474504          [692174]  137223.0
# 1      000492bf-7eaa-4939-a51c-4eef74e4c1d1                []       NaN
# 2      0004ebd0-dfd6-4276-b4a6-de0003e94237           [15862]   15870.0
# 3      0006faf6-7a61-426c-9034-579f2cfcfa83          [370780]   49283.0
# 4      00078ea3-0462-4a6e-b7b1-25fea012b2b7                []       NaN
# ...                                     ...               ...       ...
# 35744  fffa9334-3576-4f70-9605-2ad062cdbc69          [430770]   64646.0
# 35745  fffaa634-42a0-4038-b027-24f28754fec7          [571548]  101914.0
# 35746  fffcb71f-e802-436e-917d-eaa6607ab74f  [503766, 503767]   87643.0
# 35747  fffdc2ac-bde4-4e4c-a5bd-0e6c6e49ad91          [430833]   64772.0
# 35748  ffff90c3-63c4-4dee-a21d-6b2b113f4f80          [625242]  114015.0
#
#        tcgplayer_id  cardmarket_id                                    name  \
# 0          615195.0       807933.0                Nissa, Worldsoul Speaker
# 1               NaN            NaN                           Mine Security
# 2            3094.0         3081.0                              Static Orb
# 3           69965.0       262945.0                     Sensory Deprivation
# 4               NaN            NaN                        Kavaron Consumed
# ...             ...            ...                                     ...
# 35744      136683.0       298834.0                        Without Weakness
# 35745      276869.0       665173.0                 Firesong and Sunspeaker
# 35746      230214.0       530502.0  Toralf, God of Fury // Toralf's Hammer
# 35747      132234.0       298282.0                       Samut, the Tested
# 35748      505126.0       722911.0                            Sinew Sliver
#
#       lang released_at  ... produced_mana tcgplayer_etched_id loyalty  \
# 0       en  2025-02-14  ...           NaN                 NaN     NaN
# 1       en  2025-08-19  ...           NaN                 NaN     NaN
# 2       en  2001-04-11  ...           NaN                 NaN     NaN
# 3       en  2013-07-19  ...           NaN                 NaN     NaN
# 4       en  2025-08-19  ...           NaN                 NaN     NaN
# ...    ...         ...  ...           ...                 ...     ...
# 35744   en  2017-07-14  ...           NaN                 NaN     NaN
# 35745   en  2022-07-08  ...           NaN                 NaN     NaN
# 35746   en  2021-02-05  ...           NaN                 NaN     NaN
# 35747   en  2017-07-14  ...           NaN                 NaN       4
# 35748   en  2023-08-04  ...           NaN                 NaN     NaN
#
#        life_modifier hand_modifier attraction_lights color_indicator  \
# 0                NaN           NaN               NaN             NaN
# 1                NaN           NaN               NaN             NaN
# 2                NaN           NaN               NaN             NaN
# 3                NaN           NaN               NaN             NaN
# 4                NaN           NaN               NaN             NaN
# ...              ...           ...               ...             ...
# 35744            NaN           NaN               NaN             NaN
# 35745            NaN           NaN               NaN             NaN
# 35746            NaN           NaN               NaN             NaN
# 35747            NaN           NaN               NaN             NaN
# 35748            NaN           NaN               NaN             NaN
#
#        flavor_name content_warning defense
# 0              NaN             NaN     NaN
# 1              NaN             NaN     NaN
# 2              NaN             NaN     NaN
# 3              NaN             NaN     NaN
# 4              NaN             NaN     NaN
# ...            ...             ...     ...
# 35744          NaN             NaN     NaN
# 35745          NaN             NaN     NaN
# 35746          NaN             NaN     NaN
# 35747          NaN             NaN     NaN
# 35748          NaN             NaN     NaN
#
# [35749 rows x 83 columns]

# %%
# check random sample of the dataset
card_data.sample(10)
# Out:
#       object                                    id  \
# 26004   card  60e16d94-1166-4050-8554-686e153a7f80
# 19074   card  164a92ac-0788-4238-a2ed-1ebd3dd0dd88
# 35262   card  0615e930-3b6b-4b2f-a09c-0730d491545c
# 12206   card  7028130c-c91d-4bf7-b0b0-450f71107d7a
# 29127   card  cf2386fd-edc0-4731-8f4e-7a7c45548bf3
# 15700   card  72c00743-d208-4aed-939a-d70de2d759b9
# 24277   card  41142b10-a493-499a-9fc5-043eeca5d1ee
# 18568   card  89d5d2b5-3769-4341-b84e-03771dbb7491
# 20976   card  36dc7851-795b-4d59-bcd9-16d2c87d3e19
# 23809   card  153077a8-38c0-44aa-9b84-cdd9ade50ad6
#
#                                   oracle_id multiverse_ids   mtgo_id  \
# 26004  baf80db7-2ca8-4bfc-b5b6-25ed51878dd7       [423695]   62653.0
# 19074  88f935ee-7dbb-4c27-8485-f56b4193fa11        [31810]   16697.0
# 35262  fc8df5c8-fda6-454c-a1ac-21c6e3d75b9c       [527480]   91888.0
# 12206  57ce5ebd-cfac-4bb9-b010-04d0c285be27       [669123]  129663.0
# 29127  d1108bd1-87b2-4795-9690-54ff4504e04f       [457199]   71110.0
# 15700  7101f0ab-89ce-4b13-a5a8-4cabd6c8670d       [121228]   24693.0
# 24277  ae90daea-6644-4235-bca6-b94ee9925f63       [667637]  128060.0
# 18568  8582d676-54e0-41cc-a0f6-305093155458             []       NaN
# 20976  968f0edb-b81f-465a-84b2-f077af61e51b       [615336]  111370.0
# 23809  ab46b957-5206-4390-a2f6-aba2e8d1debe        [12691]   15227.0
#
#        tcgplayer_id  cardmarket_id                        name lang  \
# 26004      126405.0       294802.0  Baral, Chief of Compliance   en
# 19074        9466.0         2603.0            Engulfing Flames   en
# 35262      243393.0       571549.0                   Long Rest   en
# 12206      558580.0       777683.0      Clement, the Worrywort   en
# 29127      182820.0       368096.0         Sphinx of Foresight   en
# 15700       14037.0        13644.0                Frozen Solid   en
# 24277      555932.0       775459.0                 Arno Dorian   en
# 18568           NaN            NaN               A-Unholy Heat   en
# 20976      491502.0       705525.0             Vivien's Talent   en
# 23809        7858.0         3375.0                Radiant Kavu   en
#
#       released_at  ... produced_mana tcgplayer_etched_id loyalty  \
# 26004  2017-01-20  ...           NaN                 NaN     NaN
# 19074  2001-10-01  ...           NaN                 NaN     NaN
# 35262  2021-07-23  ...           NaN                 NaN     NaN
# 12206  2024-08-02  ...        [G, U]                 NaN     NaN
# 29127  2019-01-25  ...           NaN                 NaN     NaN
# 15700  2006-07-21  ...           NaN                 NaN     NaN
# 24277  2024-07-05  ...           NaN                 NaN     NaN
# 18568  2021-06-18  ...           NaN                 NaN     NaN
# 20976  2023-04-21  ...           NaN                 NaN     NaN
# 23809  2001-02-05  ...           NaN                 NaN     NaN
#
#        life_modifier hand_modifier attraction_lights color_indicator  \
# 26004            NaN           NaN               NaN             NaN
# 19074            NaN           NaN               NaN             NaN
# 35262            NaN           NaN               NaN             NaN
# 12206            NaN           NaN               NaN             NaN
# 29127            NaN           NaN               NaN             NaN
# 15700            NaN           NaN               NaN             NaN
# 24277            NaN           NaN               NaN             NaN
# 18568            NaN           NaN               NaN             NaN
# 20976            NaN           NaN               NaN             NaN
# 23809            NaN           NaN               NaN             NaN
#
#        flavor_name content_warning defense
# 26004          NaN             NaN     NaN
# 19074          NaN             NaN     NaN
# 35262          NaN             NaN     NaN
# 12206          NaN             NaN     NaN
# 29127          NaN             NaN     NaN
# 15700          NaN             NaN     NaN
# 24277          NaN             NaN     NaN
# 18568          NaN             NaN     NaN
# 20976          NaN             NaN     NaN
# 23809          NaN             NaN     NaN
#
# [10 rows x 83 columns]

# %%
# check datatypes, null values, and memory usage
card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35749 entries, 0 to 35748
# Data columns (total 83 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   object               35749 non-null  object
#  1   id                   35749 non-null  object
#  2   oracle_id            35749 non-null  object
#  3   multiverse_ids       35749 non-null  object
#  4   mtgo_id              26266 non-null  float64
#  5   tcgplayer_id         30372 non-null  float64
#  6   cardmarket_id        29529 non-null  float64
#  7   name                 35749 non-null  object
#  8   lang                 35749 non-null  object
#  9   released_at          35749 non-null  datetime64[ns]
#  10  uri                  35749 non-null  object
#  11  scryfall_uri         35749 non-null  object
#  12  layout               35749 non-null  object
#  13  highres_image        35749 non-null  bool
#  14  image_status         35749 non-null  object
#  15  image_uris           33274 non-null  object
#  16  mana_cost            33274 non-null  object
#  17  cmc                  35749 non-null  float64
#  18  type_line            35749 non-null  object
#  19  oracle_text          32961 non-null  object
#  20  power                18391 non-null  object
#  21  toughness            18391 non-null  object
#  22  colors               33274 non-null  object
#  23  color_identity       35749 non-null  object
#  24  keywords             35749 non-null  object
#  25  all_parts            6355 non-null   object
#  26  legalities           35749 non-null  object
#  27  games                35749 non-null  object
#  28  reserved             35749 non-null  bool
#  29  game_changer         35749 non-null  bool
#  30  foil                 35749 non-null  bool
#  31  nonfoil              35749 non-null  bool
#  32  finishes             35749 non-null  object
#  33  oversized            35749 non-null  bool
#  34  promo                35749 non-null  bool
#  35  reprint              35749 non-null  bool
#  36  variation            35749 non-null  bool
#  37  set_id               35749 non-null  object
#  38  set                  35749 non-null  object
#  39  set_name             35749 non-null  object
#  40  set_type             35749 non-null  object
#  41  set_uri              35749 non-null  object
#  42  set_search_uri       35749 non-null  object
#  43  scryfall_set_uri     35749 non-null  object
#  44  rulings_uri          35749 non-null  object
#  45  prints_search_uri    35749 non-null  object
#  46  collector_number     35749 non-null  object
#  47  digital              35749 non-null  bool
#  48  rarity               35749 non-null  object
#  49  watermark            2270 non-null   object
#  50  flavor_text          18779 non-null  object
#  51  card_back_id         33274 non-null  object
#  52  artist               35749 non-null  object
#  53  artist_ids           35092 non-null  object
#  54  illustration_id      32704 non-null  object
#  55  border_color         35749 non-null  object
#  56  frame                35749 non-null  object
#  57  frame_effects        4004 non-null   object
#  58  security_stamp       9723 non-null   object
#  59  full_art             35749 non-null  bool
#  60  textless             35749 non-null  bool
#  61  booster              35749 non-null  bool
#  62  story_spotlight      35749 non-null  bool
#  63  edhrec_rank          29838 non-null  float64
#  64  preview              8394 non-null   object
#  65  prices               35749 non-null  object
#  66  related_uris         35749 non-null  object
#  67  purchase_uris        34771 non-null  object
#  68  mtgo_foil_id         11268 non-null  float64
#  69  penny_rank           17128 non-null  float64
#  70  arena_id             9307 non-null   float64
#  71  promo_types          2961 non-null   object
#  72  card_faces           2788 non-null   object
#  73  produced_mana        2498 non-null   object
#  74  tcgplayer_etched_id  27 non-null     float64
#  75  loyalty              312 non-null    object
#  76  life_modifier        107 non-null    float64
#  77  hand_modifier        107 non-null    float64
#  78  attraction_lights    50 non-null     object
#  79  color_indicator      42 non-null     object
#  80  flavor_name          1 non-null      object
#  81  content_warning      7 non-null      float64
#  82  defense              1 non-null      float64
# dtypes: bool(14), datetime64[ns](1), float64(13), object(55)
# memory usage: 19.3+ MB

# %%
# import matplotlib for plotting
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as mtick

# set up plotting style
plt.style.use('default')

# %%
# extract prices from the dataset and check the data
card_prices = card_data[['prices']].copy()
card_prices.head()
# Out:
#                                               prices
# 0  {'usd': '0.13', 'usd_foil': None, 'usd_etched'...
# 1  {'usd': None, 'usd_foil': None, 'usd_etched': ...
# 2  {'usd': '16.74', 'usd_foil': None, 'usd_etched...
# 3  {'usd': '0.02', 'usd_foil': '0.20', 'usd_etche...
# 4  {'usd': None, 'usd_foil': None, 'usd_etched': ...

# %%
# Expand the 'prices' dictionary column into separate columns
card_prices = card_prices['prices'].apply(pd.Series)

# %%
# Count how many entries have None (or NaN) in each column
none_counts = card_prices.isna().sum()
print("Number of None/NaN values in each column:")
print(none_counts)

# Count how many rows have all None/NaN values (i.e., only None entries)
only_none_rows = card_prices.isna().all(axis=1).sum()
print(f"\nNumber of rows with only None/NaN values: {only_none_rows}")

card_prices = card_prices.dropna(how='all')
# Out:
# Number of None/NaN values in each column:
# usd            5858
# usd_foil      14613
# usd_etched    35722
# eur            6547
# eur_foil      14321
# tix           10297
# dtype: int64
#
# Number of rows with only None/NaN values: 4437

# %%
# Calculate percentage of None/NaN values for each column in card_prices
percent_none = card_prices.notna().mean() * 100
print("\nPercentage of None/NaN values in each column:")
print(percent_none)


# Plot the actual data
# Plot bars with value 100 for each entry (for reference/comparison)
plt.bar(percent_none.index, [100]*len(percent_none), color='red', alpha=0.4, label='100% Reference', width=0.5, align='center')

# Plot the actual data
ax = percent_none.plot.bar()
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.ylabel('Percentage of valid values')
plt.title('Percentage of valid values per column in card_prices')
plt.show()
# Out:
# Percentage of None/NaN values in each column:
# usd           95.461804
# usd_foil      67.501277
# usd_etched     0.086229
# eur           93.261369
# eur_foil      68.433827
# tix           81.285130
# dtype: float64

# %%
usd_prices = card_prices['usd'].dropna().astype(float)
usd_prices.sample(10)
# Out:
# 11426    0.10
# 4083     0.04
# 10289    0.05
# 11870    0.20
# 656      0.36
# 8373     6.08
# 32711    0.14
# 3286     0.08
# 8126     0.10
# 33786    0.20
# Name: usd, dtype: float64

# %%
interesting_fields = ['name', 'lang', 'mana_cost', 'released_at', 'color_identity', 'layout', 'keywords', 'loyalty', 'power', 'toughness', 'produced_mana', 'type_line', 'prices']
card_data_filtered = card_data[card_data['type_line'].str.contains('creature', case=False)][interesting_fields].copy()
card_data_filtered.sample(20)
# Out:
#                        name lang              mana_cost released_at  \
# 35193   Stampeding Elk Herd   en              {3}{G}{G}  2015-03-27
# 25172     Judge of Currents   en                 {1}{W}  2007-10-12
# 28507   Veteran Ice Climber   en                 {1}{U}  2025-04-11
# 2176         Pillarfield Ox   en                 {3}{W}  2014-06-06
# 9748    Caustic Caterpillar   en                    {G}  2015-07-17
# 32472           Shriekgeist   en                 {1}{U}  2017-11-17
# 786       Perimeter Captain   en                    {W}  2010-02-05
# 20043          Samite Elder   en                 {2}{W}  2001-02-05
# 5426    Sokenzan Spellblade   en                 {4}{R}  2005-06-03
# 409           Mistform Wall   en                 {2}{U}  2002-10-07
# 30377       Hellkite Tyrant   en              {4}{R}{R}  2024-12-02
# 34735          Plaguebearer   en                 {1}{B}  1998-06-15
# 15521        Teeka's Dragon   en                    {9}  1996-10-08
# 13248  Night Market Lookout   en                    {B}  2016-09-30
# 13579             Chronobot   en                    {2}  2021-08-20
# 26230    Holographic Double   en                    {U}  2022-03-17
# 21337  Curator of Destinies   en              {4}{U}{U}  2024-11-15
# 14290   People of the Woods   en                 {G}{G}  1994-08-01
# 24513       Sewer Crocodile   en                 {5}{U}  2022-04-29
# 19871       Arcades Sabboth   en  {2}{G}{G}{W}{W}{U}{U}  2023-01-13
#
#       color_identity  layout                    keywords loyalty power  \
# 35193            [G]  normal                [Formidable]     NaN     5
# 25172            [W]  normal                          []     NaN     1
# 28507            [U]  normal           [Vigilance, Mill]     NaN     1
# 2176             [W]  normal                          []     NaN     2
# 9748             [G]  normal                          []     NaN     1
# 32472            [U]  normal              [Flying, Mill]     NaN     1
# 786              [W]  normal                  [Defender]     NaN     0
# 20043            [W]  normal                          []     NaN     1
# 5426             [R]  normal                   [Bushido]     NaN     2
# 409              [U]  normal                          []     NaN     1
# 30377            [R]  normal           [Flying, Trample]     NaN     6
# 34735            [B]  normal                          []     NaN     1
# 15521             []  normal  [Flying, Trample, Rampage]     NaN     5
# 13248            [B]  normal                          []     NaN     1
# 13579             []  normal                          []     NaN     2
# 26230            [U]  normal                   [Conjure]     NaN     1
# 21337            [U]  normal                    [Flying]     NaN     5
# 14290            [G]  normal                          []     NaN     1
# 24513            [U]  normal                          []     NaN     4
# 19871      [G, U, W]  normal                    [Flying]     NaN     7
#
#       toughness produced_mana                          type_line  \
# 35193         5           NaN                     Creature — Elk
# 25172         1           NaN          Creature — Merfolk Wizard
# 28507         3           NaN             Creature — Human Scout
# 2176          4           NaN                      Creature — Ox
# 9748          1           NaN                  Creature — Insect
# 32472         1           NaN                  Creature — Spirit
# 786           4           NaN           Creature — Human Soldier
# 20043         2           NaN            Creature — Human Cleric
# 5426          3           NaN     Creature — Ogre Samurai Shaman
# 409           4           NaN           Creature — Illusion Wall
# 30377         5           NaN                  Creature — Dragon
# 34735         1           NaN                  Creature — Zombie
# 15521         5           NaN         Artifact Creature — Dragon
# 13248         1           NaN             Creature — Human Rogue
# 13579         2           NaN      Artifact Creature — Construct
# 26230         1           NaN                Creature — Illusion
# 21337         5           NaN                  Creature — Sphinx
# 14290         *           NaN                   Creature — Human
# 24513         6           NaN               Creature — Crocodile
# 19871         7           NaN  Legendary Creature — Elder Dragon
#
#                                                   prices
# 35193  {'usd': '0.05', 'usd_foil': '0.11', 'usd_etche...
# 25172  {'usd': '0.17', 'usd_foil': '2.85', 'usd_etche...
# 28507  {'usd': '0.05', 'usd_foil': '0.18', 'usd_etche...
# 2176   {'usd': '0.05', 'usd_foil': None, 'usd_etched'...
# 9748   {'usd': '0.14', 'usd_foil': '3.08', 'usd_etche...
# 32472  {'usd': '0.06', 'usd_foil': '0.16', 'usd_etche...
# 786    {'usd': '1.31', 'usd_foil': '6.88', 'usd_etche...
# 20043  {'usd': '0.53', 'usd_foil': '8.81', 'usd_etche...
# 5426   {'usd': '0.11', 'usd_foil': '0.69', 'usd_etche...
# 409    {'usd': '0.08', 'usd_foil': '0.50', 'usd_etche...
# 30377  {'usd': '6.66', 'usd_foil': None, 'usd_etched'...
# 34735  {'usd': '1.30', 'usd_foil': None, 'usd_etched'...
# 15521  {'usd': '6.05', 'usd_foil': None, 'usd_etched'...
# 13248  {'usd': '0.11', 'usd_foil': '0.51', 'usd_etche...
# 13579  {'usd': '0.17', 'usd_foil': None, 'usd_etched'...
# 26230  {'usd': None, 'usd_foil': None, 'usd_etched': ...
# 21337  {'usd': '0.10', 'usd_foil': '0.14', 'usd_etche...
# 14290  {'usd': '0.87', 'usd_foil': None, 'usd_etched'...
# 24513  {'usd': '0.06', 'usd_foil': '0.05', 'usd_etche...
# 19871  {'usd': '0.17', 'usd_foil': '0.22', 'usd_etche...

# %%
types = card_data_filtered['type_line'].str.split('[^A-Za-z]+').explode().value_counts().sort_values(ascending=False)
types
# Out:
# type_line
# Creature        18809
# Human            4382
# Legendary        3279
# Artifact         1372
# Warrior          1267
#                 ...
# Wrestler            1
# Triskelavite        1
# Lukka               1
# Background          1
# Island              1
# Name: count, Length: 420, dtype: int64

# %%
types[types>=50].size
# Out:
# 119

# %%
keywords = card_data_filtered.explode('keywords').value_counts('keywords').sort_values(ascending=False)
keywords
# Out:
# keywords
# Flying                3194
# Trample                959
# Vigilance              676
# Haste                  672
# Flash                  385
#                       ...
# Relentless March         1
# Psychic Stimulus         1
# Parallel Universe        1
# Bio-Plasmic Scream       1
# Ultima Founding          1
# Name: count, Length: 595, dtype: int64

# %%
keywords[keywords >= 50].size
# Out:
# 43
